# %% [markdown]
# #**LISTS**

# %%
fruits.count('apple')
# Out:
# 2

# %%
 fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']

# %%
fruits.append("mango")

# %%
fruits
# Out:
# ['orange',
#  'apple',
#  'pear',
#  'banana',
#  'kiwi',
#  'apple',
#  'banana',
#  'mango',
#  'mango']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['apple',
#  'apple',
#  'banana',
#  'banana',
#  'kiwi',
#  'mango',
#  'mango',
#  'orange',
#  'pear']

# %%
fruits.pop(1)
# Out:
# 'banana'

# %%
fruits
# Out:
# ['apple', 'banana', 'kiwi', 'mango', 'mango', 'orange', 'pear']

# %%
fruits.reverse()

# %%
fruits
# Out:
# ['pear', 'orange', 'mango', 'mango', 'kiwi', 'banana', 'apple']

# %%
fruits.insert(2,"grapes")

# %%
fruits
# Out:
# ['pear', 'orange', 'grapes', 'mango', 'mango', 'kiwi', 'banana', 'apple']

# %%
len(fruits)
# Out:
# 8

# %% [markdown]
# #**DICTIONARY**

# %%
tel = {'jack': 4098, 'sape': 4139}

# %%
tel['guido'] = 4127

# %%
tel
# Out:
# {'guido': 4127, 'jack': 4098, 'sape': 4139}

# %%
tel['sape'] = "4128"

# %%
list(tel)
# Out:
# ['jack', 'sape', 'guido']

# %%
tel
# Out:
# {'guido': 4127, 'jack': 4098, 'sape': '4128'}

# %%
tel
# Out:
# {'guido': 4127, 'jack': 4098, 'sape': '4128'}

# %%
tel
# Out:
# {'guido': 4127, 'jack': 4098, 'sape': '4128'}

# %%
'jack' in tel
# Out:
# True

# %%
"sape" not in tel
# Out:
# False

# %% [markdown]
# #**SETS**

# %%
  x = set(['foo', 'bar', 'baz', 'foo', 'qux'])

# %%
x
# Out:
# {'bar', 'baz', 'foo', 'qux'}

# %%
x
# Out:
# {'bar', 'baz', 'foo', 'qux'}

# %%
list(x)
# Out:
# ['foo', 'baz', 'bar', 'qux']

# %%
s1 = {2, 4, 6, 8,10}
s2 = {'Smith', 'McArthur', 'Wilson', 'Johansson'}

# %%
s1.union(s2)
# Out:
# {10, 2, 4, 6, 8, 'Johansson', 'McArthur', 'Smith', 'Wilson'}

# %%
y = x.union(s1)

# %%
y
# Out:
# {10, 2, 4, 6, 8, 'bar', 'baz', 'foo', 'qux'}

# %%
list(y)
# Out:
# ['foo', 2, 4, 6, 8, 10, 'baz', 'qux', 'bar']

# %% [markdown]
# #**TUPLE**

# %%
 tup1 = ('physics', 'chemistry', 1997, 2000);
tup2 = (1, 2, 3, 4, 5 );
tup3 = "a", "b", "c", "d";

# %%
tup1 = (50,);

# %%
tup2[1:5]
# Out:
# (2, 3, 4, 5)

# %%
tup4 = tup1+ tup2 + tup3;

# %%
tup4
# Out:
# (50, 1, 2, 3, 4, 5, 'a', 'b', 'c', 'd')

# %%
list(tup4)
# Out:
# [50, 1, 2, 3, 4, 5, 'a', 'b', 'c', 'd']

# %% [markdown]
# #**STRINGS**

# %%
var1 = 'Hello World!'

# %%
 var2 = "Python Programming"

# %%
var2[1:5]
# Out:
# 'ytho'

# %%
var1[:6] + 'Python'
# Out:
# 'Hello Python'
